# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 721

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        #time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # print(f"City weather query: {city_url}")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]   
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})

        # print(f"City count: {len(city_data)}")
    
    # If an error is experienced, skip the city
    except Exception as err:
        print(f"City not found. Skipping...{err}")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tura
# Processing Record 2 of Set 1 | carballo
# Processing Record 3 of Set 1 | lolua
# City not found. Skipping...'coord'
# Processing Record 4 of Set 1 | kegayli
# City not found. Skipping...'coord'
# Processing Record 5 of Set 1 | pochutla
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | amderma
# City not found. Skipping...'coord'
# Processing Record 8 of Set 1 | torbay
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | terrace bay
# Processing Record 11 of Set 1 | vanderhoof
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | beringovskiy
# Processing Record 15 of Set 1 | brookhaven
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | nyimba
# Processing Record 18 of Set 1 | uyuni
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...'coord'
# Processing Record 20 of Set 1 | kushmurun
# Processing Record 21 of Set 1 | ankazobe
# Processing Record 22 of Set 1 | laguna
# Processing Record 23 of Set 1 | bambous virieux
# Processing Record 24 of Set 1 | caucaia
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | lebork
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | haines junction
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | los llanos de aridane
# Processing Record 33 of Set 1 | rio grande
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | tessalit
# Processing Record 36 of Set 1 | saskylakh
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | kaniama
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | itaituba
# Processing Record 41 of Set 1 | lebu
# Processing Record 42 of Set 1 | tumannyy
# City not found. Skipping...'coord'
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | itaporanga
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | sao gabriel da cachoeira
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | vila
# Processing Record 50 of Set 1 | axim
# Processing Record 1 of Set 2 | bairiki
# Processing Record 2 of Set 2 | ust-tsilma
# Processing Record 3 of Set 2 | lasa
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | la ronge
# Processing Record 6 of Set 2 | upernavik
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | nyrob
# Processing Record 9 of Set 2 | barbar
# City not found. Skipping...'coord'
# Processing Record 10 of Set 2 | yining
# Processing Record 11 of Set 2 | noumea
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | pevek
# Processing Record 14 of Set 2 | havre-saint-pierre
# Processing Record 15 of Set 2 | tuatapere
# Processing Record 16 of Set 2 | ahipara
# Processing Record 17 of Set 2 | coreau
# Processing Record 18 of Set 2 | pangnirtung
# Processing Record 19 of Set 2 | clyde river
# Processing Record 20 of Set 2 | saint george
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | coquimbo
# Processing Record 23 of Set 2 | half moon bay
# Processing Record 24 of Set 2 | jumla
# Processing Record 25 of Set 2 | nguiu
# City not found. Skipping...'coord'
# Processing Record 26 of Set 2 | aklavik
# Processing Record 27 of Set 2 | batagay
# Processing Record 28 of Set 2 | illoqqortoormiut
# City not found. Skipping...'coord'
# Processing Record 29 of Set 2 | sao filipe
# Processing Record 30 of Set 2 | padang
# Processing Record 31 of Set 2 | talnakh
# Processing Record 32 of Set 2 | barrow
# Processing Record 33 of Set 2 | esperance
# Processing Record 34 of Set 2 | carnarvon
# Processing Record 35 of Set 2 | myitkyina
# Processing Record 36 of Set 2 | new norfolk
# Processing Record 37 of Set 2 | mahebourg
# Processing Record 38 of Set 2 | barentsburg
# City not found. Skipping...'coord'
# Processing Record 39 of Set 2 | praya
# Processing Record 40 of Set 2 | faanui
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | albany
# Processing Record 43 of Set 2 | xingyi
# Processing Record 44 of Set 2 | khatanga
# Processing Record 45 of Set 2 | carnot
# Processing Record 46 of Set 2 | progreso
# Processing Record 47 of Set 2 | georgetown
# Processing Record 48 of Set 2 | bluff
# Processing Record 49 of Set 2 | labuhan
# Processing Record 50 of Set 2 | tyumentsevo
# Processing Record 1 of Set 3 | bolungarvik
# City not found. Skipping...'coord'
# Processing Record 2 of Set 3 | sanghar
# Processing Record 3 of Set 3 | cap malheureux
# Processing Record 4 of Set 3 | hasaki
# Processing Record 5 of Set 3 | lorengau
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | sacalum
# Processing Record 8 of Set 3 | atuona
# Processing Record 9 of Set 3 | biryukove
# Processing Record 10 of Set 3 | tupik
# Processing Record 11 of Set 3 | longyearbyen
# Processing Record 12 of Set 3 | taoudenni
# Processing Record 13 of Set 3 | mar del plata
# Processing Record 14 of Set 3 | san cristobal
# Processing Record 15 of Set 3 | kuna
# Processing Record 16 of Set 3 | provideniya
# Processing Record 17 of Set 3 | port lincoln
# Processing Record 18 of Set 3 | viligili
# City not found. Skipping...'coord'
# Processing Record 19 of Set 3 | kleck
# City not found. Skipping...'coord'
# Processing Record 20 of Set 3 | vao
# Processing Record 21 of Set 3 | hithadhoo
# Processing Record 22 of Set 3 | beloha
# Processing Record 23 of Set 3 | cherskiy
# Processing Record 24 of Set 3 | rio gallegos
# Processing Record 25 of Set 3 | grindavik
# Processing Record 26 of Set 3 | vardo
# Processing Record 27 of Set 3 | andenes
# Processing Record 28 of Set 3 | kavaratti
# Processing Record 29 of Set 3 | east london
# Processing Record 30 of Set 3 | pacific grove
# Processing Record 31 of Set 3 | ilulissat
# Processing Record 32 of Set 3 | mozhaysk
# Processing Record 33 of Set 3 | puga
# Processing Record 34 of Set 3 | codrington
# Processing Record 35 of Set 3 | san fernando
# Processing Record 36 of Set 3 | coihaique
# Processing Record 37 of Set 3 | ballina
# Processing Record 38 of Set 3 | sawtell
# Processing Record 39 of Set 3 | la huerta
# Processing Record 40 of Set 3 | guerrero negro
# Processing Record 41 of Set 3 | puerto ayacucho
# Processing Record 42 of Set 3 | constitucion
# Processing Record 43 of Set 3 | ilula
# Processing Record 44 of Set 3 | saint-augustin
# Processing Record 45 of Set 3 | pisco
# Processing Record 46 of Set 3 | mys shmidta
# City not found. Skipping...'coord'
# Processing Record 47 of Set 3 | vaini
# Processing Record 48 of Set 3 | roma
# Processing Record 49 of Set 3 | tilichiki
# Processing Record 50 of Set 3 | east wenatchee bench
# Processing Record 1 of Set 4 | ancud
# Processing Record 2 of Set 4 | strezhevoy
# Processing Record 3 of Set 4 | nemuro
# Processing Record 4 of Set 4 | mzimba
# Processing Record 5 of Set 4 | berlevag
# Processing Record 6 of Set 4 | puerto escondido
# Processing Record 7 of Set 4 | thompson
# Processing Record 8 of Set 4 | harlingen
# Processing Record 9 of Set 4 | la union
# Processing Record 10 of Set 4 | sao felix do xingu
# Processing Record 11 of Set 4 | lompoc
# Processing Record 12 of Set 4 | yellowknife
# Processing Record 13 of Set 4 | gorontalo
# Processing Record 14 of Set 4 | brora
# Processing Record 15 of Set 4 | zhovtneve
# Processing Record 16 of Set 4 | butaritari
# Processing Record 17 of Set 4 | kupang
# Processing Record 18 of Set 4 | maragogi
# Processing Record 19 of Set 4 | necochea
# Processing Record 20 of Set 4 | airai
# Processing Record 21 of Set 4 | iqaluit
# Processing Record 22 of Set 4 | kloulklubed
# Processing Record 23 of Set 4 | katete
# Processing Record 24 of Set 4 | bubaque
# Processing Record 25 of Set 4 | samalaeulu
# City not found. Skipping...'coord'
# Processing Record 26 of Set 4 | kandrian
# Processing Record 27 of Set 4 | lagdo
# Processing Record 28 of Set 4 | marcona
# City not found. Skipping...'coord'
# Processing Record 29 of Set 4 | vadso
# Processing Record 30 of Set 4 | waingapu
# Processing Record 31 of Set 4 | tiznit
# Processing Record 32 of Set 4 | weatherford
# Processing Record 33 of Set 4 | sibolga
# Processing Record 34 of Set 4 | purnia
# Processing Record 35 of Set 4 | dakoro
# Processing Record 36 of Set 4 | rujewa
# Processing Record 37 of Set 4 | mitu
# Processing Record 38 of Set 4 | lagoa
# Processing Record 39 of Set 4 | kenai
# Processing Record 40 of Set 4 | cidreira
# Processing Record 41 of Set 4 | lake city
# Processing Record 42 of Set 4 | norman wells
# Processing Record 43 of Set 4 | vysokogornyy
# Processing Record 44 of Set 4 | chuy
# Processing Record 45 of Set 4 | hokitika
# Processing Record 46 of Set 4 | vestmannaeyjar
# Processing Record 47 of Set 4 | mansehra
# Processing Record 48 of Set 4 | primero de enero
# Processing Record 49 of Set 4 | kiama
# Processing Record 50 of Set 4 | belushya guba
# City not found. Skipping...'coord'
# Processing Record 1 of Set 5 | geraldton
# Processing Record 2 of Set 5 | paradwip
# City not found. Skipping...'coord'
# Processing Record 3 of Set 5 | xuddur
# Processing Record 4 of Set 5 | te anau
# Processing Record 5 of Set 5 | klaksvik
# Processing Record 6 of Set 5 | tokur
# Processing Record 7 of Set 5 | pingliang
# Processing Record 8 of Set 5 | kurtamysh
# Processing Record 9 of Set 5 | bethel
# Processing Record 10 of Set 5 | touros
# Processing Record 11 of Set 5 | tezu
# Processing Record 12 of Set 5 | de aar
# Processing Record 13 of Set 5 | meyungs
# City not found. Skipping...'coord'
# Processing Record 14 of Set 5 | katobu
# Processing Record 15 of Set 5 | ipiau
# Processing Record 16 of Set 5 | kerman
# Processing Record 17 of Set 5 | broome
# Processing Record 18 of Set 5 | mullaitivu
# City not found. Skipping...'coord'
# Processing Record 19 of Set 5 | kaitangata
# Processing Record 20 of Set 5 | meulaboh
# Processing Record 21 of Set 5 | pizhanka
# Processing Record 22 of Set 5 | fort nelson
# Processing Record 23 of Set 5 | ruatoria
# City not found. Skipping...'coord'
# Processing Record 24 of Set 5 | roald
# Processing Record 25 of Set 5 | palmer
# Processing Record 26 of Set 5 | ust-nera
# Processing Record 27 of Set 5 | ceyhan
# Processing Record 28 of Set 5 | bria
# Processing Record 29 of Set 5 | brightwater
# Processing Record 30 of Set 5 | caconda
# Processing Record 31 of Set 5 | kahului
# Processing Record 32 of Set 5 | awbari
# Processing Record 33 of Set 5 | caravelas
# Processing Record 34 of Set 5 | comodoro rivadavia
# Processing Record 35 of Set 5 | mount isa
# Processing Record 36 of Set 5 | foz do iguacu
# Processing Record 37 of Set 5 | bentiu
# Processing Record 38 of Set 5 | ritchie
# Processing Record 39 of Set 5 | misratah
# Processing Record 40 of Set 5 | colares
# Processing Record 41 of Set 5 | tigre
# Processing Record 42 of Set 5 | mogochin
# City not found. Skipping...'coord'
# Processing Record 43 of Set 5 | karaul
# City not found. Skipping...'coord'
# Processing Record 44 of Set 5 | lucea
# Processing Record 45 of Set 5 | huarmey
# Processing Record 46 of Set 5 | saleaula
# City not found. Skipping...'coord'
# Processing Record 47 of Set 5 | vygonichi
# Processing Record 48 of Set 5 | ucluelet
# Processing Record 49 of Set 5 | svetlogorsk
# Processing Record 50 of Set 5 | cabo san lucas
# Processing Record 1 of Set 6 | bengkulu
# Processing Record 2 of Set 6 | castro
# Processing Record 3 of Set 6 | beruwala
# Processing Record 4 of Set 6 | coesfeld
# Processing Record 5 of Set 6 | evans
# Processing Record 6 of Set 6 | terrace
# Processing Record 7 of Set 6 | kavieng
# Processing Record 8 of Set 6 | yaan
# Processing Record 9 of Set 6 | ryotsu
# Processing Record 10 of Set 6 | port-cartier
# Processing Record 11 of Set 6 | mount gambier
# Processing Record 12 of Set 6 | mansa
# Processing Record 13 of Set 6 | xuanzhou
# Processing Record 14 of Set 6 | point pedro
# Processing Record 15 of Set 6 | vostok
# Processing Record 16 of Set 6 | kawalu
# Processing Record 17 of Set 6 | nacala
# Processing Record 18 of Set 6 | bogovarovo
# Processing Record 19 of Set 6 | bilibino
# Processing Record 20 of Set 6 | huaihua
# Processing Record 21 of Set 6 | nizhneyansk
# City not found. Skipping...'coord'
# Processing Record 22 of Set 6 | bridlington
# Processing Record 23 of Set 6 | maniwaki
# Processing Record 24 of Set 6 | itacare
# Processing Record 25 of Set 6 | sijunjung
# Processing Record 26 of Set 6 | sorvag
# City not found. Skipping...'coord'
# Processing Record 27 of Set 6 | teknaf
# Processing Record 28 of Set 6 | chikoy
# City not found. Skipping...'coord'
# Processing Record 29 of Set 6 | schwedt
# Processing Record 30 of Set 6 | kjollefjord
# Processing Record 31 of Set 6 | bluefield
# Processing Record 32 of Set 6 | ambilobe
# Processing Record 33 of Set 6 | mbandaka
# Processing Record 34 of Set 6 | grand gaube
# Processing Record 35 of Set 6 | anadyr
# Processing Record 36 of Set 6 | falealupo
# City not found. Skipping...'coord'
# Processing Record 37 of Set 6 | marzuq
# Processing Record 38 of Set 6 | aqtobe
# Processing Record 39 of Set 6 | san antonio
# Processing Record 40 of Set 6 | del rio
# Processing Record 41 of Set 6 | yashan
# Processing Record 42 of Set 6 | minot
# Processing Record 43 of Set 6 | turbat
# Processing Record 44 of Set 6 | ransang
# Processing Record 45 of Set 6 | grand-santi
# Processing Record 46 of Set 6 | sharjah
# Processing Record 47 of Set 6 | ambon
# Processing Record 48 of Set 6 | abbeville
# Processing Record 49 of Set 6 | vaitupu
# City not found. Skipping...'coord'
# Processing Record 50 of Set 6 | sokoni
# Processing Record 1 of Set 7 | tawkar
# City not found. Skipping...'coord'
# Processing Record 2 of Set 7 | tuktoyaktuk
# Processing Record 3 of Set 7 | corner brook
# Processing Record 4 of Set 7 | mayo
# Processing Record 5 of Set 7 | fairbanks
# Processing Record 6 of Set 7 | tiksi
# Processing Record 7 of Set 7 | lopatyn
# Processing Record 8 of Set 7 | anori
# Processing Record 9 of Set 7 | navrongo
# Processing Record 10 of Set 7 | babadag
# Processing Record 11 of Set 7 | srednekolymsk
# Processing Record 12 of Set 7 | rungata
# City not found. Skipping...'coord'
# Processing Record 13 of Set 7 | nangomba
# Processing Record 14 of Set 7 | grand river south east
# City not found. Skipping...'coord'
# Processing Record 15 of Set 7 | nador
# Processing Record 16 of Set 7 | karlshamn
# Processing Record 17 of Set 7 | marsabit
# Processing Record 18 of Set 7 | mitsamiouli
# Processing Record 19 of Set 7 | hualmay
# Processing Record 20 of Set 7 | tsienyane
# City not found. Skipping...'coord'
# Processing Record 21 of Set 7 | bud
# Processing Record 22 of Set 7 | tabiauea
# City not found. Skipping...'coord'
# Processing Record 23 of Set 7 | hofn
# Processing Record 24 of Set 7 | bowen
# Processing Record 25 of Set 7 | severo-kurilsk
# Processing Record 26 of Set 7 | nerchinskiy zavod
# Processing Record 27 of Set 7 | mehamn
# Processing Record 28 of Set 7 | houston
# Processing Record 29 of Set 7 | doctor pedro p. pena
# City not found. Skipping...'coord'
# Processing Record 30 of Set 7 | trinidad
# Processing Record 31 of Set 7 | la gomera
# Processing Record 32 of Set 7 | mopipi
# Processing Record 33 of Set 7 | muros
# Processing Record 34 of Set 7 | goksun
# Processing Record 35 of Set 7 | ekhabi
# Processing Record 36 of Set 7 | henties bay
# Processing Record 37 of Set 7 | samusu
# City not found. Skipping...'coord'
# Processing Record 38 of Set 7 | saint-pierre
# Processing Record 39 of Set 7 | yulara
# Processing Record 40 of Set 7 | rosendal
# Processing Record 41 of Set 7 | el zulia
# Processing Record 42 of Set 7 | nanortalik
# Processing Record 43 of Set 7 | chute-aux-outardes
# Processing Record 44 of Set 7 | saldanha
# Processing Record 45 of Set 7 | attawapiskat
# City not found. Skipping...'coord'
# Processing Record 46 of Set 7 | villafranca de los barros
# Processing Record 47 of Set 7 | teya
# Processing Record 48 of Set 7 | saryshagan
# City not found. Skipping...'coord'
# Processing Record 49 of Set 7 | goure
# Processing Record 50 of Set 7 | asau
# Processing Record 1 of Set 8 | zhanaozen
# Processing Record 2 of Set 8 | palestina
# Processing Record 3 of Set 8 | sitka
# Processing Record 4 of Set 8 | marsh harbour
# Processing Record 5 of Set 8 | marabba
# Processing Record 6 of Set 8 | bolobo
# Processing Record 7 of Set 8 | saint marys
# Processing Record 8 of Set 8 | rimini
# Processing Record 9 of Set 8 | kaduqli
# Processing Record 10 of Set 8 | barmer
# Processing Record 11 of Set 8 | salalah
# Processing Record 12 of Set 8 | tevriz
# Processing Record 13 of Set 8 | kitui
# Processing Record 14 of Set 8 | saint stephen
# Processing Record 15 of Set 8 | namibe
# Processing Record 16 of Set 8 | dingle
# Processing Record 17 of Set 8 | isangel
# Processing Record 18 of Set 8 | hwange
# Processing Record 19 of Set 8 | doha
# Processing Record 20 of Set 8 | kapit
# Processing Record 21 of Set 8 | pucallpa
# Processing Record 22 of Set 8 | port hardy
# Processing Record 23 of Set 8 | ponta do sol
# Processing Record 24 of Set 8 | lingyuan
# Processing Record 25 of Set 8 | shimoda
# Processing Record 26 of Set 8 | kamenskoye
# City not found. Skipping...'coord'
# Processing Record 27 of Set 8 | tiarei
# Processing Record 28 of Set 8 | bira
# Processing Record 29 of Set 8 | benghazi
# Processing Record 30 of Set 8 | lyubim
# Processing Record 31 of Set 8 | victoria
# Processing Record 32 of Set 8 | emba
# Processing Record 33 of Set 8 | kirksville
# Processing Record 34 of Set 8 | gizo
# Processing Record 35 of Set 8 | narsaq
# Processing Record 36 of Set 8 | wewak
# Processing Record 37 of Set 8 | bluefields
# Processing Record 38 of Set 8 | luan
# Processing Record 39 of Set 8 | lamar
# Processing Record 40 of Set 8 | sept-iles
# Processing Record 41 of Set 8 | menongue
# Processing Record 42 of Set 8 | ksenyevka
# City not found. Skipping...'coord'
# Processing Record 43 of Set 8 | ogulin
# Processing Record 44 of Set 8 | meadow lake
# Processing Record 45 of Set 8 | rocha
# Processing Record 46 of Set 8 | guymon
# Processing Record 47 of Set 8 | patiya
# Processing Record 48 of Set 8 | mrirt
# City not found. Skipping...'coord'
# Processing Record 49 of Set 8 | kaputa
# Processing Record 50 of Set 8 | makung
# City not found. Skipping...'coord'
# Processing Record 1 of Set 9 | leningradskiy
# Processing Record 2 of Set 9 | birao
# Processing Record 3 of Set 9 | anderson
# Processing Record 4 of Set 9 | chokurdakh
# Processing Record 5 of Set 9 | prainha
# Processing Record 6 of Set 9 | rio branco
# Processing Record 7 of Set 9 | margate
# Processing Record 8 of Set 9 | port blair
# Processing Record 9 of Set 9 | edd
# Processing Record 10 of Set 9 | namatanai
# Processing Record 11 of Set 9 | mangrol
# Processing Record 12 of Set 9 | marsa matruh
# Processing Record 13 of Set 9 | da lat
# Processing Record 14 of Set 9 | tarudant
# City not found. Skipping...'coord'
# Processing Record 15 of Set 9 | hammelburg
# Processing Record 16 of Set 9 | chernyshevskiy
# Processing Record 17 of Set 9 | monticello
# Processing Record 18 of Set 9 | huambo
# Processing Record 19 of Set 9 | constantine
# Processing Record 20 of Set 9 | sabang
# Processing Record 21 of Set 9 | santa cruz
# Processing Record 22 of Set 9 | forio
# Processing Record 23 of Set 9 | merauke
# Processing Record 24 of Set 9 | buraydah
# Processing Record 25 of Set 9 | birjand
# Processing Record 26 of Set 9 | tricase
# Processing Record 27 of Set 9 | la cruz
# Processing Record 28 of Set 9 | monroe
# Processing Record 29 of Set 9 | keetmanshoop
# Processing Record 30 of Set 9 | sulangan
# Processing Record 31 of Set 9 | bosaso
# Processing Record 32 of Set 9 | tsihombe
# City not found. Skipping...'coord'
# Processing Record 33 of Set 9 | olafsvik
# Processing Record 34 of Set 9 | alyangula
# Processing Record 35 of Set 9 | yelan
# Processing Record 36 of Set 9 | usinsk
# Processing Record 37 of Set 9 | mokhsogollokh
# Processing Record 38 of Set 9 | qarqin
# Processing Record 39 of Set 9 | ellisras
# Processing Record 40 of Set 9 | cururupu
# Processing Record 41 of Set 9 | tsaratanana
# Processing Record 42 of Set 9 | nynashamn
# Processing Record 43 of Set 9 | ketchikan
# Processing Record 44 of Set 9 | saint-philippe
# Processing Record 45 of Set 9 | owosso
# Processing Record 46 of Set 9 | kirovskiy
# Processing Record 47 of Set 9 | poya
# Processing Record 48 of Set 9 | sayyan
# Processing Record 49 of Set 9 | taltal
# Processing Record 50 of Set 9 | humenne
# Processing Record 1 of Set 10 | sao francisco de assis
# Processing Record 2 of Set 10 | wanaka
# Processing Record 3 of Set 10 | kaeo
# Processing Record 4 of Set 10 | broken hill
# Processing Record 5 of Set 10 | kruisfontein
# Processing Record 6 of Set 10 | gat
# Processing Record 7 of Set 10 | kneza
# City not found. Skipping...'coord'
# Processing Record 8 of Set 10 | hooksett
# Processing Record 9 of Set 10 | lethem
# Processing Record 10 of Set 10 | shingu
# Processing Record 11 of Set 10 | zhigansk
# Processing Record 12 of Set 10 | juifang
# City not found. Skipping...'coord'
# Processing Record 13 of Set 10 | rafai
# Processing Record 14 of Set 10 | shaartuz
# City not found. Skipping...'coord'
# Processing Record 15 of Set 10 | jinxiang
# Processing Record 16 of Set 10 | harper
# Processing Record 17 of Set 10 | santarem
# Processing Record 18 of Set 10 | gao
# Processing Record 19 of Set 10 | urbana
# Processing Record 20 of Set 10 | kuzhithurai
# Processing Record 21 of Set 10 | kharp
# Processing Record 22 of Set 10 | souillac
# Processing Record 23 of Set 10 | moranbah
# Processing Record 24 of Set 10 | talaya
# Processing Record 25 of Set 10 | punta cardon
# Processing Record 26 of Set 10 | gustavo diaz ordaz
# Processing Record 27 of Set 10 | jiazi
# Processing Record 28 of Set 10 | bama
# Processing Record 29 of Set 10 | petropavlivka
# Processing Record 30 of Set 10 | christchurch
# Processing Record 31 of Set 10 | khandyga
# Processing Record 32 of Set 10 | bhag
# Processing Record 33 of Set 10 | kavarna
# Processing Record 34 of Set 10 | marhaura
# Processing Record 35 of Set 10 | linhares
# Processing Record 36 of Set 10 | suchiapa
# Processing Record 37 of Set 10 | san patricio
# Processing Record 38 of Set 10 | sentyabrskiy
# City not found. Skipping...'coord'
# Processing Record 39 of Set 10 | mezen
# Processing Record 40 of Set 10 | kidal
# Processing Record 41 of Set 10 | hudson bay
# Processing Record 42 of Set 10 | laurel
# Processing Record 43 of Set 10 | verkhnevilyuysk
# Processing Record 44 of Set 10 | nizhniy tsasuchey
# Processing Record 45 of Set 10 | south yuba city
# Processing Record 46 of Set 10 | malpe
# Processing Record 47 of Set 10 | taitung
# Processing Record 48 of Set 10 | santa lucia
# Processing Record 49 of Set 10 | greenfield
# Processing Record 50 of Set 10 | scottsburgh
# City not found. Skipping...'coord'
# Processing Record 1 of Set 11 | maridi
# Processing Record 2 of Set 11 | alihe
# Processing Record 3 of Set 11 | berezovyy
# Processing Record 4 of Set 11 | zakharovo
# Processing Record 5 of Set 11 | cape girardeau
# Processing Record 6 of Set 11 | flinders
# Processing Record 7 of Set 11 | asfi
# Processing Record 8 of Set 11 | rapid valley
# Processing Record 9 of Set 11 | malwan
# City not found. Skipping...'coord'
# Processing Record 10 of Set 11 | san policarpo
# Processing Record 11 of Set 11 | nanga eboko
# Processing Record 12 of Set 11 | beohari
# Processing Record 13 of Set 11 | iskateley
# Processing Record 14 of Set 11 | yarensk
# Processing Record 15 of Set 11 | kodinsk
# Processing Record 16 of Set 11 | malakal
# Processing Record 17 of Set 11 | shekhupura
# Processing Record 18 of Set 11 | palabuhanratu
# City not found. Skipping...'coord'
# Processing Record 19 of Set 11 | hay river
# Processing Record 20 of Set 11 | ericeira
# Processing Record 21 of Set 11 | hamilton
# Processing Record 22 of Set 11 | fortuna
# Processing Record 23 of Set 11 | moratuwa
# Processing Record 24 of Set 11 | luena
# Processing Record 25 of Set 11 | adrian
# Processing Record 26 of Set 11 | vaitape
# Processing Record 27 of Set 11 | shinuhayr
# Processing Record 28 of Set 11 | prince rupert
# Processing Record 29 of Set 11 | armilla
# Processing Record 30 of Set 11 | tahe
# Processing Record 31 of Set 11 | douentza
# Processing Record 32 of Set 11 | san jose
# Processing Record 33 of Set 11 | catamayo
# Processing Record 34 of Set 11 | nelson bay
# Processing Record 35 of Set 11 | chitungwiza
# Processing Record 36 of Set 11 | camacupa
# Processing Record 37 of Set 11 | faya
# Processing Record 38 of Set 11 | planeta rica
# Processing Record 39 of Set 11 | zarubino
# Processing Record 40 of Set 11 | boguchany
# Processing Record 41 of Set 11 | xining
# Processing Record 42 of Set 11 | chulym
# Processing Record 43 of Set 11 | suileng
# Processing Record 44 of Set 11 | thohoyandou
# Processing Record 45 of Set 11 | mabaruma
# Processing Record 46 of Set 11 | cumaribo
# City not found. Skipping...'coord'
# Processing Record 47 of Set 11 | luderitz
# Processing Record 48 of Set 11 | port-gentil
# Processing Record 49 of Set 11 | lata
# Processing Record 50 of Set 11 | asind
# Processing Record 1 of Set 12 | juodupe
# Processing Record 2 of Set 12 | smidovich
# Processing Record 3 of Set 12 | thinadhoo
# Processing Record 4 of Set 12 | morondava
# Processing Record 5 of Set 12 | nadym
# Processing Record 6 of Set 12 | duluth
# Processing Record 7 of Set 12 | bougouni
# Processing Record 8 of Set 12 | portland
# Processing Record 9 of Set 12 | concordia
# Processing Record 10 of Set 12 | humaita
# Processing Record 11 of Set 12 | ascoli piceno
# Processing Record 12 of Set 12 | louga
# Processing Record 13 of Set 12 | iralaya
# Processing Record 14 of Set 12 | maldonado
# Processing Record 15 of Set 12 | leh
# Processing Record 16 of Set 12 | walvis bay
# Processing Record 17 of Set 12 | ustyuzhna
# Processing Record 18 of Set 12 | vila franca do campo
# Processing Record 19 of Set 12 | chimore
# Processing Record 20 of Set 12 | raudeberg
# Processing Record 21 of Set 12 | kamyshin
# Processing Record 22 of Set 12 | pecos
# Processing Record 23 of Set 12 | warragul
# Processing Record 24 of Set 12 | rivera
# Processing Record 25 of Set 12 | kifri
# Processing Record 26 of Set 12 | sawakin
# Processing Record 27 of Set 12 | sidi ali
# Processing Record 28 of Set 12 | luanda
# Processing Record 29 of Set 12 | ulaanbaatar
# Processing Record 30 of Set 12 | upington
# Processing Record 31 of Set 12 | platanos
# Processing Record 32 of Set 12 | betanzos
# Processing Record 33 of Set 12 | fort saint john
# City not found. Skipping...'coord'
# Processing Record 34 of Set 12 | simao
# Processing Record 35 of Set 12 | ossora
# Processing Record 36 of Set 12 | wattegama
# Processing Record 37 of Set 12 | nelson
# Processing Record 38 of Set 12 | bac lieu
# Processing Record 39 of Set 12 | smithers
# Processing Record 40 of Set 12 | najran
# Processing Record 41 of Set 12 | pitanga
# Processing Record 42 of Set 12 | brae
# Processing Record 43 of Set 12 | sabha
# Processing Record 44 of Set 12 | quime
# Processing Record 45 of Set 12 | moengo
# Processing Record 46 of Set 12 | westport
# Processing Record 47 of Set 12 | alta floresta
# Processing Record 48 of Set 12 | jutai
# Processing Record 49 of Set 12 | avera
# Processing Record 50 of Set 12 | alofi
# Processing Record 1 of Set 13 | pervomayskoye
# Processing Record 2 of Set 13 | visnes
# Processing Record 3 of Set 13 | san carlos
# Processing Record 4 of Set 13 | altar
# Processing Record 5 of Set 13 | turukhansk
# Processing Record 6 of Set 13 | idrinskoye
# Processing Record 7 of Set 13 | shiyan
# Processing Record 8 of Set 13 | karratha
# Processing Record 9 of Set 13 | umzimvubu
# City not found. Skipping...'coord'
# Processing Record 10 of Set 13 | nantucket
# Processing Record 11 of Set 13 | sabancuy
# Processing Record 12 of Set 13 | presidencia roque saenz pena
# Processing Record 13 of Set 13 | alotau
# City not found. Skipping...'coord'
# Processing Record 14 of Set 13 | biak
# Processing Record 15 of Set 13 | cabinda
# Processing Record 16 of Set 13 | belyy yar
# Processing Record 17 of Set 13 | nijar
# Processing Record 18 of Set 13 | la quinta
# Processing Record 19 of Set 13 | daru
# Processing Record 20 of Set 13 | sao francisco do sul
# Processing Record 21 of Set 13 | itape
# Processing Record 22 of Set 13 | jacareacanga
# Processing Record 23 of Set 13 | kuytun
# Processing Record 24 of Set 13 | bani walid
# Processing Record 25 of Set 13 | naron
# Processing Record 26 of Set 13 | omsukchan
# Processing Record 27 of Set 13 | vidim
# Processing Record 28 of Set 13 | ruidoso
# Processing Record 29 of Set 13 | lhanbryde
# Processing Record 30 of Set 13 | melville
# Processing Record 31 of Set 13 | eureka
# Processing Record 32 of Set 13 | bontang
# Processing Record 33 of Set 13 | zeya
# Processing Record 34 of Set 13 | wuwei
# Processing Record 35 of Set 13 | vallenar
# Processing Record 36 of Set 13 | tabuk
# Processing Record 37 of Set 13 | luganville
# Processing Record 38 of Set 13 | kant
# Processing Record 39 of Set 13 | duz
# City not found. Skipping...'coord'
# Processing Record 40 of Set 13 | adrar
# Processing Record 41 of Set 13 | hobyo
# Processing Record 42 of Set 13 | igrim
# Processing Record 43 of Set 13 | havoysund
# Processing Record 44 of Set 13 | mount pleasant
# Processing Record 45 of Set 13 | itainopolis
# Processing Record 46 of Set 13 | boyolangu
# Processing Record 47 of Set 13 | katsuura
# Processing Record 48 of Set 13 | nome
# Processing Record 49 of Set 13 | wolmaranstad
# City not found. Skipping...'coord'
# Processing Record 50 of Set 13 | vangaindrano
# Processing Record 1 of Set 14 | erzin
# Processing Record 2 of Set 14 | naze
# Processing Record 3 of Set 14 | san andres
# Processing Record 4 of Set 14 | muzhi
# Processing Record 5 of Set 14 | sturgeon falls
# Processing Record 6 of Set 14 | cedar city
# Processing Record 7 of Set 14 | puerto quijarro
# Processing Record 8 of Set 14 | sinnamary
# Processing Record 9 of Set 14 | the valley
# Processing Record 10 of Set 14 | praia da vitoria
# Processing Record 11 of Set 14 | altamira
# Processing Record 12 of Set 14 | maputo
# Processing Record 13 of Set 14 | dolbeau
# City not found. Skipping...'coord'
# Processing Record 14 of Set 14 | pasinler
# Processing Record 15 of Set 14 | soure
# Processing Record 16 of Set 14 | eregli
# Processing Record 17 of Set 14 | yeppoon
# Processing Record 18 of Set 14 | save
# Processing Record 19 of Set 14 | abu samrah
# Processing Record 20 of Set 14 | parrita
# Processing Record 21 of Set 14 | pangai
# Processing Record 22 of Set 14 | masindi
# Processing Record 23 of Set 14 | komsomolskiy
# Processing Record 24 of Set 14 | vanavara
# Processing Record 25 of Set 14 | riyadh
# Processing Record 26 of Set 14 | montgomery village
# Processing Record 27 of Set 14 | calderitas
# Processing Record 28 of Set 14 | mapiripan
# Processing Record 29 of Set 14 | honningsvag
# Processing Record 30 of Set 14 | lappersdorf
# Processing Record 31 of Set 14 | gobabis
# Processing Record 32 of Set 14 | sola
# Processing Record 33 of Set 14 | nampula
# Processing Record 34 of Set 14 | urengoy
# Processing Record 35 of Set 14 | fevralsk
# City not found. Skipping...'coord'
# Processing Record 36 of Set 14 | jarabacoa
# Processing Record 37 of Set 14 | kutum
# Processing Record 38 of Set 14 | kedrovyy
# Processing Record 39 of Set 14 | mazamari
# Processing Record 40 of Set 14 | sira
# Processing Record 41 of Set 14 | mae ramat
# Processing Record 42 of Set 14 | cockburn town
# Processing Record 43 of Set 14 | wajima
# Processing Record 44 of Set 14 | richards bay
# Processing Record 45 of Set 14 | loikaw
# Processing Record 46 of Set 14 | bodden town
# Processing Record 47 of Set 14 | socorro
# Processing Record 48 of Set 14 | nizwa
# Processing Record 49 of Set 14 | vila velha
# Processing Record 50 of Set 14 | carikar
# City not found. Skipping...'coord'
# Processing Record 1 of Set 15 | benguela
# Processing Record 2 of Set 15 | chicama
# Processing Record 3 of Set 15 | natal
# Processing Record 4 of Set 15 | spornoye
# Processing Record 5 of Set 15 | fort morgan
# Processing Record 6 of Set 15 | manbij
# Processing Record 7 of Set 15 | san lorenzo
# Processing Record 8 of Set 15 | parabel
# Processing Record 9 of Set 15 | pedasi
# Processing Record 10 of Set 15 | west bay
# Processing Record 11 of Set 15 | jalpan
# Processing Record 12 of Set 15 | sur
# Processing Record 13 of Set 15 | sakakah
# Processing Record 14 of Set 15 | ola
# Processing Record 15 of Set 15 | lishui
# Processing Record 16 of Set 15 | ziro
# Processing Record 17 of Set 15 | kalianget
# Processing Record 18 of Set 15 | mareeba
# Processing Record 19 of Set 15 | ayan
# Processing Record 20 of Set 15 | barvinkove
# Processing Record 21 of Set 15 | buala
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 662

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Tura  25.5198   90.2201    294.08        96          91        1.54
# 1     Carballo  43.2130   -8.6910    290.96        86          62        3.13
# 2     Pochutla  15.7432  -96.4661    300.27        66           3        0.82
# 3  Port Alfred -33.5906   26.8910    288.25        85          93        4.90
# 4       Torbay  47.6666  -52.7314    286.35        68          20        8.23
# 5   Bredasdorp -34.5322   20.0403    290.62        51          29        8.72
# 6  Terrace Bay  48.7834  -87.1000    279.17        84          67        1.87
# 7   Vanderhoof  54.0166 -124.0198    272.37        74         100        1.31
# 8    Jamestown  42.0970  -79.2353    286.92        92         100        2.57
# 9      Rikitea -23.1203 -134.9692    293.47        82         100        2.74
#
#   Country Current Description
# 0      IN     overcast clouds
# 1      ES       broken clouds
# 2      MX           clear sky
# 3      ZA     overcast clouds
# 4      CA          few clouds
# 5      ZA    scattered clouds
# 6      CA       broken clouds
# 7      CA     overcast clouds
# 8      US     overcast clouds
# 9      PF          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Tura      IN  25.5198   90.2201    294.08        96          91
# 1     Carballo      ES  43.2130   -8.6910    290.96        86          62
# 2     Pochutla      MX  15.7432  -96.4661    300.27        66           3
# 3  Port Alfred      ZA -33.5906   26.8910    288.25        85          93
# 4       Torbay      CA  47.6666  -52.7314    286.35        68          20
# 5   Bredasdorp      ZA -34.5322   20.0403    290.62        51          29
# 6  Terrace Bay      CA  48.7834  -87.1000    279.17        84          67
# 7   Vanderhoof      CA  54.0166 -124.0198    272.37        74         100
# 8    Jamestown      US  42.0970  -79.2353    286.92        92         100
# 9      Rikitea      PF -23.1203 -134.9692    293.47        82         100
#
#    Wind Speed Current Description
# 0        1.54     overcast clouds
# 1        3.13       broken clouds
# 2        0.82           clear sky
# 3        4.90     overcast clouds
# 4        8.23          few clouds
# 5        8.72    scattered clouds
# 6        1.87       broken clouds
# 7        1.31     overcast clouds
# 8        2.57     overcast clouds
# 9        2.74          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
